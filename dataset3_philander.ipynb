# %% [markdown]
# # Task 1: Perform an Exploratory Data Analysis on a Given Dataset (5 marks)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
import pandas as pd

data = pd.read_csv('data/03_transaction_records.csv')

# %%
data.head()
# Out:
#    FISCAL_YR  FISCAL_MTH          DEPT_NAME                 DIV_NAME  \
# 0       2017           1  DEPT OF EDUCATION  DEPARTMENT OF EDUCATION
# 1       2017           1  DEPT OF EDUCATION  DEPARTMENT OF EDUCATION
# 2       2017           1  DEPT OF EDUCATION  DEPARTMENT OF EDUCATION
# 3       2017           1  DEPT OF EDUCATION  DEPARTMENT OF EDUCATION
# 4       2017           1  DEPT OF EDUCATION  DEPARTMENT OF EDUCATION
#
#                     MERCHANT                   CAT_DESC   TRANS_DT    AMT
# 0  DOUBLETREE HOTELS WASHING                    LODGING   6/3/2016  -5.50
# 1  HYATT REGENCY NW ORLE F/B  EATING PLACES RESTAURANTS  6/26/2016  18.31
# 2  HYATT REGENCY NW ORLE F/B  EATING PLACES RESTAURANTS  6/26/2016  21.61
# 3  HYATT REGENCY NW ORLE F/B  EATING PLACES RESTAURANTS  6/26/2016  22.39
# 4  HYATT REGENCY NW ORLE F/B  EATING PLACES RESTAURANTS  6/26/2016   5.44

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15156 entries, 0 to 15155
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FISCAL_YR   15156 non-null  int64
#  1   FISCAL_MTH  15156 non-null  int64
#  2   DEPT_NAME   15156 non-null  object
#  3   DIV_NAME    15156 non-null  object
#  4   MERCHANT    15156 non-null  object
#  5   CAT_DESC    15156 non-null  object
#  6   TRANS_DT    15156 non-null  object
#  7   AMT         15156 non-null  float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 947.4+ KB

# %%
data.isnull().sum()
# Out:
# FISCAL_YR     0
# FISCAL_MTH    0
# DEPT_NAME     0
# DIV_NAME      0
# MERCHANT      0
# CAT_DESC      0
# TRANS_DT      0
# AMT           0
# dtype: int64

# %%
data.describe()
# Out:
#           FISCAL_YR    FISCAL_MTH           AMT
# count  15156.000000  15156.000000  15156.000000
# mean    2019.156374      6.293019    315.448271
# std        1.661039      3.542863   1530.714012
# min     2017.000000      1.000000 -12849.300000
# 25%     2018.000000      3.000000     16.090000
# 50%     2019.000000      6.000000     48.990000
# 75%     2021.000000     10.000000    264.162500
# max     2022.000000     12.000000  88501.320000

# %%
data.describe(include=['object'])
# Out:
#                 DEPT_NAME                 DIV_NAME  MERCHANT  \
# count               15156                    15156     15156
# unique                  1                       25      5802
# top     DEPT OF EDUCATION  DEPARTMENT OF EDUCATION  WB MASON
# freq                15156                     4675       293
#
#                          CAT_DESC  TRANS_DT
# count                       15156     15156
# unique                        208      1851
# top     Eating Places Restaurants  5/1/2019
# freq                         1544        85

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of 'AMT' (Amount)
plt.figure(figsize=(10, 6))
sns.histplot(data['AMT'], kde=True)
plt.title('Distribution of Transaction Amounts (AMT)')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# The transaction amount has a large range with a lot of it being around 0, which explains why the histogram looks like this.

# %%
# Count plot for 'DIV_NAME' (Top 10)
plt.figure(figsize=(10, 6))
sns.countplot(y=data['DIV_NAME'], order=data['DIV_NAME'].value_counts().iloc[:10].index)
plt.title('Top 10 Divisions by Number of Transactions')
plt.xlabel('Number of Transactions')
plt.ylabel('Division Name')
plt.show()

# %% [markdown]
# We can see that the top 2 are the same but with different spelling, so that needs to be cleaned later on.

# %%
# Count plot for 'CAT_DESC' (Top 10)
plt.figure(figsize=(10, 6))
sns.countplot(y=data['CAT_DESC'], order=data['CAT_DESC'].value_counts().iloc[:10].index)
plt.title('Top 10 Categories by Number of Transactions')
plt.xlabel('Number of Transactions')
plt.ylabel('Category Description')
plt.show()

# %% [markdown]
# Similarly for this, cleaning has to be done.

# %%
# Count plot for 'MERCHANT' (Top 10)
plt.figure(figsize=(10, 6))
sns.countplot(y=data['MERCHANT'], order=data['MERCHANT'].value_counts().iloc[:10].index)
plt.title('Top 10 Merchants by Number of Transactions')
plt.xlabel('Number of Transactions')
plt.ylabel('Merchant Name')
plt.show()

# %%
# Transaction counts by fiscal year and month
plt.figure(figsize=(12, 6))
data['YEAR_MONTH'] = data['FISCAL_YR'].astype(str) + '-' + data['FISCAL_MTH'].astype(str).str.zfill(2)
sns.countplot(x='YEAR_MONTH', data=data)
plt.xticks(rotation=90)
plt.title('Number of Transactions Per Fiscal Year and Month')
plt.xlabel('Fiscal Year-Month')
plt.ylabel('Number of Transactions')
plt.show()

# %% [markdown]
# There is no real pattern regarding the number of transactions in relation to the fiscal year and month.

# %%
for columns in data:
    print(columns, len(data[columns].unique()))
# Out:
# FISCAL_YR 6
# FISCAL_MTH 12
# DEPT_NAME 1
# DIV_NAME 25
# MERCHANT 5802
# CAT_DESC 208
# TRANS_DT 1851
# AMT 7851
# YEAR_MONTH 66

# %% [markdown]
# Merchant and Transaction Date column have too many unique values, which would result in a very sparse dataset which would be computationally expensive for the model to run, hence I will drop these 2 columns.

# %% [markdown]
# ## Data Cleaning

# %%
new_data = data.drop(['MERCHANT', 'TRANS_DT', 'YEAR_MONTH'], axis=1)

# %% [markdown]
# Removing the 2 columns with a lot of unique values.

# %%
new_data['DIV_NAME'] = new_data['DIV_NAME'].str.lower()
new_data['CAT_DESC'] = new_data['CAT_DESC'].str.lower()

# %% [markdown]
# # Task 2: Train, validate and develop a Machine Learning pipeline using PyCaret. (10 marks)

# %%
from pycaret.anomaly import *
from pycaret.anomaly import AnomalyExperiment
# exp = AnomalyExperiment()

# Initialize PyCaret setup
exp = setup(new_data, 
        session_id=123,  # Set a seed for reproducibility
        normalize=True,  # Normalize numerical features
        transformation=True,  # Apply power transformation
        log_experiment='mlflow',# Enable experiment logging
        experiment_name='anomaly_detection_experiment')
# Out:
# <style type="text/css">
# #T_513bc_row5_col1, #T_513bc_row11_col1, #T_513bc_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_513bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_513bc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_513bc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_513bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_513bc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_513bc_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_513bc_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_513bc_row1_col1" class="data row1 col1" >(15156, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_513bc_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_513bc_row2_col1" class="data row2 col1" >(15156, 144)</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_513bc_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_513bc_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_513bc_row4_col0" class="data row4 col0" >Categorical features</td>
#       <td id="T_513bc_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_513bc_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_513bc_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_513bc_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_513bc_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_513bc_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_513bc_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_513bc_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_513bc_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_513bc_row9_col0" class="data row9 col0" >Maximum one-hot encoding</td>
#       <td id="T_513bc_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_513bc_row10_col0" class="data row10 col0" >Encoding method</td>
#       <td id="T_513bc_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_513bc_row11_col0" class="data row11 col0" >Transformation</td>
#       <td id="T_513bc_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_513bc_row12_col0" class="data row12 col0" >Transformation method</td>
#       <td id="T_513bc_row12_col1" class="data row12 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_513bc_row13_col0" class="data row13 col0" >Normalize</td>
#       <td id="T_513bc_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_513bc_row14_col0" class="data row14 col0" >Normalize method</td>
#       <td id="T_513bc_row14_col1" class="data row14 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_513bc_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_513bc_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_513bc_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_513bc_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_513bc_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_513bc_row17_col1" class="data row17 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_513bc_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_513bc_row18_col1" class="data row18 col1" >anomaly_detection_experiment</td>
#     </tr>
#     <tr>
#       <th id="T_513bc_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_513bc_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_513bc_row19_col1" class="data row19 col1" >cf7e</td>
#     </tr>
#   </tbody>
# </table>

# %%
type(exp)
# Out:
# pycaret.anomaly.oop.AnomalyExperiment

# %%
# train iforest model
iforest = create_model('iforest')
iforest
# Out:
# IForest(behaviour='new', bootstrap=False, contamination=0.05,
#     max_features=1.0, max_samples='auto', n_estimators=100, n_jobs=-1,
#     random_state=123, verbose=0)

# %%
models()
# Out:
#                                         Name  \
# ID
# abod            Angle-base Outlier Detection
# cluster       Clustering-Based Local Outlier
# cof         Connectivity-Based Local Outlier
# iforest                     Isolation Forest
# histogram  Histogram-based Outlier Detection
# knn             K-Nearest Neighbors Detector
# lof                     Local Outlier Factor
# svm                   One-class SVM detector
# pca             Principal Component Analysis
# mcd           Minimum Covariance Determinant
# sod               Subspace Outlier Detection
# sos             Stochastic Outlier Selection
#
#                                                   Reference
# ID
# abod                                  pyod.models.abod.ABOD
# cluster    pycaret.internal.patches.pyod.CBLOFForceToDouble
# cof                                     pyod.models.cof.COF
# iforest                         pyod.models.iforest.IForest
# histogram                             pyod.models.hbos.HBOS
# knn                                     pyod.models.knn.KNN
# lof                                     pyod.models.lof.LOF
# svm                                 pyod.models.ocsvm.OCSVM
# pca                                     pyod.models.pca.PCA
# mcd                                     pyod.models.mcd.MCD
# sod                                     pyod.models.sod.SOD
# sos                                     pyod.models.sos.SOS

# %%
iforest_anomalies = assign_model(iforest)
iforest_anomalies
# Out:
#        FISCAL_YR  FISCAL_MTH          DEPT_NAME                 DIV_NAME  \
# 0           2017           1  DEPT OF EDUCATION  department of education
# 1           2017           1  DEPT OF EDUCATION  department of education
# 2           2017           1  DEPT OF EDUCATION  department of education
# 3           2017           1  DEPT OF EDUCATION  department of education
# 4           2017           1  DEPT OF EDUCATION  department of education
# ...          ...         ...                ...                      ...
# 15151       2022           6  DEPT OF EDUCATION         academic support
# 15152       2022           6  DEPT OF EDUCATION         academic support
# 15153       2022           6  DEPT OF EDUCATION         academic support
# 15154       2022           6  DEPT OF EDUCATION          student support
# 15155       2022           6  DEPT OF EDUCATION          student support
#
#                                                CAT_DESC         AMT  Anomaly  \
# 0                                               lodging   -5.500000        0
# 1                             eating places restaurants   18.309999        0
# 2                             eating places restaurants   21.610001        0
# 3                             eating places restaurants   22.389999        0
# 4                             eating places restaurants    5.440000        0
# ...                                                 ...         ...      ...
# 15151                                        car rental   52.580002        0
# 15152                                           lodging   14.910000        0
# 15153                                           lodging  111.000000        0
# 15154  schools educational svc-not elsewhere classified   99.989998        1
# 15155  schools educational svc-not elsewhere classified   99.989998        1
#
#        Anomaly_Score
# 0          -0.040981
# 1          -0.048571
# 2          -0.048571
# 3          -0.048571
# 4          -0.048431
# ...              ...
# 15151      -0.015579
# 15152      -0.019484
# 15153      -0.019047
# 15154       0.029821
# 15155       0.029821
#
# [15156 rows x 8 columns]

# %%
# predict on test set
iforest_pred = predict_model(iforest, data=new_data)
iforest_pred
# Out:
#           FISCAL_YR  FISCAL_MTH  DEPT_NAME_DEPT OF EDUCATION  \
# 0     -1.110223e-16   -1.652399                          0.0
# 1     -1.110223e-16   -1.652399                          0.0
# 2     -1.110223e-16   -1.652399                          0.0
# 3     -1.110223e-16   -1.652399                          0.0
# 4     -1.110223e-16   -1.652399                          0.0
# ...             ...         ...                          ...
# 15151  1.110223e-16    0.015835                          0.0
# 15152  1.110223e-16    0.015835                          0.0
# 15153  1.110223e-16    0.015835                          0.0
# 15154  1.110223e-16    0.015835                          0.0
# 15155  1.110223e-16    0.015835                          0.0
#
#        DIV_NAME_department of education  DIV_NAME_education block grants  \
# 0                              0.862016                        -0.269465
# 1                              0.862016                        -0.269465
# 2                              0.862016                        -0.269465
# 3                              0.862016                        -0.269465
# 4                              0.862016                        -0.269465
# ...                                 ...                              ...
# 15151                         -1.160072                        -0.269465
# 15152                         -1.160072                        -0.269465
# 15153                         -1.160072                        -0.269465
# 15154                         -1.160072                        -0.269465
# 15155                         -1.160072                        -0.269465
#
#        DIV_NAME_special needs programs  DIV_NAME_advisory council  \
# 0                            -0.356734                   -0.09229
# 1                            -0.356734                   -0.09229
# 2                            -0.356734                   -0.09229
# 3                            -0.356734                   -0.09229
# 4                            -0.356734                   -0.09229
# ...                                ...                        ...
# 15151                        -0.356734                   -0.09229
# 15152                        -0.356734                   -0.09229
# 15153                        -0.356734                   -0.09229
# 15154                        -0.356734                   -0.09229
# 15155                        -0.356734                   -0.09229
#
#        DIV_NAME_transportation  DIV_NAME_driver training  \
# 0                    -0.067627                 -0.045998
# 1                    -0.067627                 -0.045998
# 2                    -0.067627                 -0.045998
# 3                    -0.067627                 -0.045998
# 4                    -0.067627                 -0.045998
# ...                        ...                       ...
# 15151                -0.067627                 -0.045998
# 15152                -0.067627                 -0.045998
# 15153                -0.067627                 -0.045998
# 15154                -0.067627                 -0.045998
# 15155                -0.067627                 -0.045998
#
#        DIV_NAME_other items  ...  CAT_DESC_automotive tire stores  \
# 0                 -0.131077  ...                        -0.016248
# 1                 -0.131077  ...                        -0.016248
# 2                 -0.131077  ...                        -0.016248
# 3                 -0.131077  ...                        -0.016248
# 4                 -0.131077  ...                        -0.016248
# ...                     ...  ...                              ...
# 15151             -0.131077  ...                        -0.016248
# 15152             -0.131077  ...                        -0.016248
# 15153             -0.131077  ...                        -0.016248
# 15154             -0.131077  ...                        -0.016248
# 15155             -0.131077  ...                        -0.016248
#
#        CAT_DESC_insurance sales underwriting and premiums  \
# 0                                              -0.014071
# 1                                              -0.014071
# 2                                              -0.014071
# 3                                              -0.014071
# 4                                              -0.014071
# ...                                                  ...
# 15151                                          -0.014071
# 15152                                          -0.014071
# 15153                                          -0.014071
# 15154                                          -0.014071
# 15155                                          -0.014071
#
#        CAT_DESC_schools correspondence  CAT_DESC_record shops  \
# 0                            -0.008123              -0.028149
# 1                            -0.008123              -0.028149
# 2                            -0.008123              -0.028149
# 3                            -0.008123              -0.028149
# 4                            -0.008123              -0.028149
# ...                                ...                    ...
# 15151                        -0.008123              -0.028149
# 15152                        -0.008123              -0.028149
# 15153                        -0.008123              -0.028149
# 15154                        -0.008123              -0.028149
# 15155                        -0.008123              -0.028149
#
#        CAT_DESC_cleaning garment and laundry services  \
# 0                                           -0.008123
# 1                                           -0.008123
# 2                                           -0.008123
# 3                                           -0.008123
# 4                                           -0.008123
# ...                                               ...
# 15151                                       -0.008123
# 15152                                       -0.008123
# 15153                                       -0.008123
# 15154                                       -0.008123
# 15155                                       -0.008123
#
#        CAT_DESC_candy nut confectionery stores  \
# 0                                    -0.008123
# 1                                    -0.008123
# 2                                    -0.008123
# 3                                    -0.008123
# 4                                    -0.008123
# ...                                        ...
# 15151                                -0.008123
# 15152                                -0.008123
# 15153                                -0.008123
# 15154                                -0.008123
# 15155                                -0.008123
#
#        CAT_DESC_bar lounge disco nightclub tavern-alcoholic drinks       AMT  \
# 0                                              -0.011488           -0.246585
# 1                                              -0.011488           -0.213448
# 2                                              -0.011488           -0.209732
# 3                                              -0.011488           -0.208863
# 4                                              -0.011488           -0.228865
# ...                                                  ...                 ...
# 15151                                          -0.011488           -0.177068
# 15152                                          -0.011488           -0.217354
# 15153                                          -0.011488           -0.120789
# 15154                                          -0.011488           -0.131063
# 15155                                          -0.011488           -0.131063
#
#        Anomaly  Anomaly_Score
# 0            0      -0.040981
# 1            0      -0.048571
# 2            0      -0.048571
# 3            0      -0.048571
# 4            0      -0.048431
# ...        ...            ...
# 15151        0      -0.015579
# 15152        0      -0.019484
# 15153        0      -0.019047
# 15154        1       0.029821
# 15155        1       0.029821
#
# [15156 rows x 146 columns]

# %% [markdown]
# ## Save model as pkl file

# %%
save_model(iforest, 'models/anomaly_detection_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['FISCAL_YR', 'FISCAL_MTH', 'AMT'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['DEPT_NAME', 'DIV_NAME',
#                                               'CAT_DESC'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['DEPT_N...
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('transformation',
#                   TransformerWrapper(transformer=PowerTransformer(standardize=False))),
#                  ('normalize', TransformerWrapper(transformer=StandardScaler())),
#                  ('trained_model',
#                   IForest(behaviour='new', bootstrap=False, contamination=0.05,
#      max_features=1.0, max_samples='auto', n_estimators=100, n_jobs=-1,
#      random_state=123, verbose=0))]),
#  'models/anomaly_detection_model.pkl')
